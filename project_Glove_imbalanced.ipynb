# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

trueData = '/content/drive/MyDrive/Btech_project/True.csv'
fakeData = '/content/drive/MyDrive/Btech_project/Fake.csv'

true_Df = pd.read_csv(trueData)
fake_Df = pd.read_csv(fakeData)

# %%
display(fake_Df)
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 0      Donald Trump just couldn t wish all Americans ...         News
# 1      House Intelligence Committee Chairman Devin Nu...         News
# 2      On Friday, it was revealed that former Milwauk...         News
# 3      On Christmas day, Donald Trump announced that ...         News
# 4      Pope Francis used his annual Christmas Day mes...         News
# ...                                                  ...          ...
# 23476  21st Century Wire says As 21WIRE reported earl...  Middle-east
# 23477  21st Century Wire says It s a familiar theme. ...  Middle-east
# 23478  Patrick Henningsen  21st Century WireRemember ...  Middle-east
# 23479  21st Century Wire says Al Jazeera America will...  Middle-east
# 23480  21st Century Wire says As 21WIRE predicted in ...  Middle-east
#
#                     date
# 0      December 31, 2017
# 1      December 31, 2017
# 2      December 30, 2017
# 3      December 29, 2017
# 4      December 25, 2017
# ...                  ...
# 23476   January 16, 2016
# 23477   January 16, 2016
# 23478   January 15, 2016
# 23479   January 14, 2016
# 23480   January 12, 2016
#
# [23481 rows x 4 columns]

# %%
display(true_Df)
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...     worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...     worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...     worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...     worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...     worldnews
#
#                      date
# 0      December 31, 2017
# 1      December 29, 2017
# 2      December 31, 2017
# 3      December 30, 2017
# 4      December 29, 2017
# ...                   ...
# 21412    August 22, 2017
# 21413    August 22, 2017
# 21414    August 22, 2017
# 21415    August 22, 2017
# 21416    August 22, 2017
#
# [21417 rows x 4 columns]

# %% [markdown]
# ***WordCloud for Real News***

# %%
from wordcloud import WordCloud
import seaborn as sns
import matplotlib.pyplot as plt


real_Titles = true_Df.title
real_allWords = ' '.join(real_Titles)
real_WordCloud = WordCloud(background_color='Black',
    width= 800, height= 500,
    max_font_size = 180,
    collocations = False).generate(real_allWords)

plt.figure(figsize=(10,7))
plt.imshow(real_WordCloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ***WordCloud for fake news***

# %%
fake_Titles = fake_Df.title
fake_allWords = ' '.join(fake_Titles)
fake_WordCloud = WordCloud(background_color='Black',
    width= 800, height= 500,
    max_font_size = 180,
    collocations = False).generate(fake_allWords)

plt.figure(figsize=(10,7))
plt.imshow(fake_WordCloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ***Data Visualization***

# %%
sns.countplot(y="subject", palette="coolwarm", data=true_Df).set_title('Subject Distribution for true news')
plt.show()

# %%
sns.countplot(y="subject", palette="coolwarm", data=fake_Df).set_title('Subject Distribution for fake news')
plt.show()

# %% [markdown]
# ***Data Preprocessing***

# %%
true_Df['label'] = 1
fake_Df['label'] = 0


df = pd.concat([true_Df, fake_Df])
display(df)
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 23476  21st Century Wire says As 21WIRE reported earl...   Middle-east
# 23477  21st Century Wire says It s a familiar theme. ...   Middle-east
# 23478  Patrick Henningsen  21st Century WireRemember ...   Middle-east
# 23479  21st Century Wire says Al Jazeera America will...   Middle-east
# 23480  21st Century Wire says As 21WIRE predicted in ...   Middle-east
#
#                      date  label
# 0      December 31, 2017       1
# 1      December 29, 2017       1
# 2      December 31, 2017       1
# 3      December 30, 2017       1
# 4      December 29, 2017       1
# ...                   ...    ...
# 23476    January 16, 2016      0
# 23477    January 16, 2016      0
# 23478    January 15, 2016      0
# 23479    January 14, 2016      0
# 23480    January 12, 2016      0
#
# [44898 rows x 5 columns]

# %% [markdown]
# ***Inspecting Length of News titles***

# %%
titles = [text for text in df.title]

max_len = 0
titles_len = []
for title in titles:
    titles_len.append(len(title.split()))
    max_len = max(len(title.split()), max_len)

print('Number of titles:', len(titles))
print('Max length of the titles:', max_len)
print('Mean length of the titles:', np.mean(titles_len))
# Out:
# Number of titles: 44898
# Max length of the titles: 42
# Mean length of the titles: 12.453472315025168

# %% [markdown]
# ***Inspecting length of News statements***

# %%
texts = [text for text in df.text]

max_len = 0
texts_len = []
for text in texts:
    texts_len.append(len(text.split()))
    max_len = max(len(text.split()), max_len)

print('Mean length of the texts:', np.mean(texts_len))
# Out:
# Mean length of the texts: 405.28228428883244

# %% [markdown]
# ***Purifying and shuffling the dataframe***

# %%
from sklearn.utils import shuffle

# Purify
df = df.iloc[:,[0, -1]]

# Shuffle
df = shuffle(df).reset_index(drop=True)

display(df)
# Out:
#                                                    title  label
# 0      Britain's 'thrilled' Prince Harry announces he...      1
# 1      Trump on Hurricane Irma: 'This is some big mon...      1
# 2      Kuwait arrests five over video deemed offensiv...      1
# 3       Suspects in Malta blogger's murder sent to trial      1
# 4      Indian Prime Minister Modi to visit Washington...      1
# ...                                                  ...    ...
# 44893  'Let's get emotional' says German SPD, struggl...      1
# 44894  WATCH JOE BIDEN’S Shocking Anti-Gun Comment Ab...      0
# 44895  Myanmar, Bangladesh sign Rohingya return deal:...      1
# 44896  Big financial woes linger in Illinois' new budget      1
# 44897  Hostile same-sex marriage vote spurs Australia...      1
#
# [44898 rows x 2 columns]

# %% [markdown]
# ***Splitting data into training, validation and testing.***

# %%
train_validate_df = df.sample(frac = 0.8)
test_df = df.drop(train_validate_df.index)

train_df = train_validate_df.sample(frac = 0.8)
validation_df = train_validate_df.drop(train_df.index)

# Reset Index
train_df = train_df.reset_index(drop=True)
validation_df = validation_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

print('train_dataset size:', train_df.shape)
print('validation_dataset size:', validation_df.shape)
print('testing_dataset size:', test_df.shape)
# Out:
# train_dataset size: (28734, 2)
# validation_dataset size: (7184, 2)
# testing_dataset size: (8980, 2)

# %%
train_imbalanced = 1/10
val_imbalanced = 1/10
test_imbalanced = 1/10

train_true = train_df[train_df['label'] == 1]
train_fake = train_df[train_df['label'] == 0]
train_fake = train_fake.iloc[:round(len(train_fake)*train_imbalanced),:]
train_true_len = len(train_true)
train_fake_len = len(train_fake)
train_df = pd.concat([train_true, train_fake])
train_df = shuffle(train_df).reset_index(drop=True)

val_true = validation_df[validation_df['label'] == 1]
val_fake = validation_df[validation_df['label'] == 0]
val_fake = val_fake.iloc[:round(len(val_fake)*val_imbalanced),:]
val_true_len = len(val_true)
val_fake_len = len(val_fake)
val_df = pd.concat([val_true, val_fake])
val_df = shuffle(val_df).reset_index(drop=True)

test_true = test_df[test_df['label'] == 1]
test_fake = test_df[test_df['label'] == 0]
test_fake = test_fake.iloc[:round(len(test_fake)*test_imbalanced),:]
test_true_len = len(test_true)
test_fake_len = len(test_fake)
test_df = pd.concat([test_true, test_fake])
test_df = shuffle(test_df).reset_index(drop=True)

len_df = pd.DataFrame({'ind': ['Train', 'Validation', 'Test'], 'True': [train_true_len, val_true_len, test_true_len], 'Fake': [train_fake_len, val_fake_len, test_fake_len]})
len_df.set_index('ind', inplace=True)
len_df.index.name = None

len_df
# Out:
#              True  Fake
# Train       13679  1506
# Validation   3437   375
# Test         4301   468

# %%
train_df.to_csv('train.tsv', sep='\t', index=False)
validation_df.to_csv('val.tsv', sep='\t', index=False)
test_df.to_csv('test.tsv', sep='\t', index=False)

# %%
df = pd.concat([train_df, validation_df, test_df])
df.to_csv('non.csv',index=False)

# %%
import nltk
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
#def tokenize(column):
  #tokens = nltk.word_tokenize(column)
  #return [w for w in tokens if w.isalpha()]

# %%
#df['tokenized'] = df.apply(lambda x: tokenize(x['title']), axis=1)
#df[['tokenized']].head()

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
df = pd.read_csv('non.csv')

def lemmatize_word(word):
    return lemmatizer.lemmatize(word, pos='v')

df['lemmatized_column'] = df['title'].apply(lambda x: ' '.join([lemmatize_word(word) for word in x.split()]))

df.to_csv('lemmatized.csv', index=False)

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

# %%
print(stop_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'from', 'subject', 're', 'edu', 'use']

# %%
import gensim

# %%
def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3 and token not in stop_words:
            result.append(token)
            
    return result

# %%
df = pd.read_csv('lemmatized.csv')
df['clean'] = df['lemmatized_column'].apply(preprocess)
df
# Out:
#                                                    title  label  \
# 0      Trump to tap nuclear industry lobbyist for U.S...      1
# 1      Trump to order reversal of Obama water regulat...      1
# 2      U.N. envoy told North Korea urgent need to ope...      1
# 3      Kremlin: Syria, oil high on Putin's agenda on ...      1
# 4      Libyan rivals split over army leadership: Trip...      1
# ...                                                  ...    ...
# 27133  U.S. 'making a lot of progress' on North Korea...      1
# 27134  Reuters/Ipsos States of the Nation: Clinton le...      1
# 27135  A cell signal, an open bar: tiny wins for Puer...      1
# 27136  Matchmaker Merkel seeks awkward three-way embrace      1
# 27137  HILLARY CLINTON PROVES SHE DOESN’T “PLAY WELL ...      0
#
#                                        lemmatized_column  \
# 0      Trump to tap nuclear industry lobbyist for U.S...
# 1      Trump to order reversal of Obama water regulat...
# 2      U.N. envoy tell North Korea urgent need to ope...
# 3      Kremlin: Syria, oil high on Putin's agenda on ...
# 4      Libyan rival split over army leadership: Tripo...
# ...                                                  ...
# 27133  U.S. 'making a lot of progress' on North Korea...
# 27134  Reuters/Ipsos States of the Nation: Clinton le...
# 27135  A cell signal, an open bar: tiny win for Puert...
# 27136   Matchmaker Merkel seek awkward three-way embrace
# 27137  HILLARY CLINTON PROVES SHE DOESN’T “PLAY WELL ...
#
#                                                    clean
# 0      [trump, nuclear, industry, lobbyist, energy, d...
# 1      [trump, order, reversal, obama, water, regulat...
# 2      [envoy, tell, north, korea, urgent, need, open...
# 3      [kremlin, syria, high, putin, agenda, trip, iran]
# 4      [libyan, rival, split, army, leadership, tripo...
# ...                                                  ...
# 27133     [making, progress, north, korea, issue, trump]
# 27134  [reuters, ipsos, states, nation, clinton, lead...
# 27135     [cell, signal, open, tiny, puerto, rico, ruin]
# 27136       [matchmaker, merkel, seek, awkward, embrace]
# 27137  [hillary, clinton, proves, play, names, greate...
#
# [27138 rows x 4 columns]

# %%
list_of_words = []
for i in df.clean:
    for j in i:
        list_of_words.append(j)

total_words = len(list(set(list_of_words)))
total_words
# Out:
# 14566

# %%
pip list | grep tensorflow
# Out:
# tensorflow                    2.12.0
# tensorflow-datasets           4.8.3
# tensorflow-estimator          2.12.0
# tensorflow-gcs-config         2.12.0
# tensorflow-hub                0.13.0
# tensorflow-io-gcs-filesystem  0.32.0
# tensorflow-metadata           1.13.1
# tensorflow-probability        0.19.0

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Embedding, Input, LSTM, Conv1D, MaxPool1D, Bidirectional, Dropout, BatchNormalization
import numpy as np

# %%
# Load the data
train_data = pd.read_csv('train.tsv', delimiter='\t')
test_data = pd.read_csv('test.tsv', delimiter='\t')
validation_data = pd.read_csv('val.tsv', delimiter='\t')

# %%
# Creating A Tokenizer To Tokenize The Words And Create Sequences Of Tokenized Words
tokenizer = Tokenizer(num_words = total_words)
tokenizer.fit_on_texts(train_df['title'])

# Convert the texts to sequences
train_sequences = tokenizer.texts_to_sequences(train_data['title'])
validation_sequences = tokenizer.texts_to_sequences(validation_data['title'])
test_sequences = tokenizer.texts_to_sequences(test_data['title'])

# %%
# Get the maximum sequence length
max_sequence_length = max(len(seq) for seq in train_sequences)
max_sequence_length
# Out:
# 38

# %%
# Pad the sequences
train_padded = pad_sequences(train_sequences, maxlen=max_sequence_length, padding='post', truncating='post')
test_padded = pad_sequences(test_sequences, maxlen=max_sequence_length, padding='post', truncating='post')
validation_padded = pad_sequences(validation_sequences, maxlen=max_sequence_length, padding='post', truncating='post')

# %%
# Define the embedding dimension
embedding_dim = 100

# Load the GloVe embeddings
embeddings_index = {}
glove_file = '/content/drive/MyDrive/Btech_project/glove.6B.100d.txt'
with open(glove_file, encoding='utf8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs

f.close()

# %%
# Create the embedding matrix
word_index = tokenizer.word_index
num_words = len(word_index) + 1
embedding_matrix = np.zeros((num_words, embedding_dim))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, Input, Dense, Flatten, Conv1D, MaxPooling1D, LSTM, Bidirectional, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
#Define the CNN-BiLSTM model

from keras.regularizers import l2

input_layer = Input(shape=(max_sequence_length,), dtype='int32')
embedding_layer = Embedding(num_words, embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length)(input_layer)
embedding_dropout_layer = Dropout(0.5)(embedding_layer)
conv_layer = Conv1D(filters=16, kernel_size=3, padding='same', activation='relu')(embedding_dropout_layer)
conv_dropout_layer = Dropout(0.5)(conv_layer)
pool_layer = MaxPooling1D(pool_size=2)(conv_dropout_layer)
bilstm_layer = Bidirectional(LSTM(units=32, dropout=0.5, recurrent_dropout=0.5))(pool_layer)
bilstm_dropout_layer = Dropout(0.5)(bilstm_layer)
output_layer = Dense(1, activation='sigmoid', kernel_regularizer=l2(0.01))(bilstm_dropout_layer)
cnn_bilstm_model = Model(inputs=input_layer, outputs=output_layer)

# %%
#Compile the CNN-BiLSTM model
cnn_bilstm_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
print(cnn_bilstm_model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 38)]              0
#
#  embedding (Embedding)       (None, 38, 100)           1583600
#
#  dropout (Dropout)           (None, 38, 100)           0
#
#  conv1d (Conv1D)             (None, 38, 16)            4816
#
#  dropout_1 (Dropout)         (None, 38, 16)            0
#
#  max_pooling1d (MaxPooling1D  (None, 19, 16)           0
#  )
#
#  bidirectional (Bidirectiona  (None, 64)               12544
#  l)
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 1,601,025
# Trainable params: 1,601,025
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Train the CNN-BiLSTM model
cnn_bilstm_model.fit(train_padded, train_data['label'], validation_data=(validation_padded, validation_data['label']), epochs=15, batch_size=32)
# Out:
# Epoch 1/15
# 475/475 [==============================] - 51s 77ms/step - loss: 0.2450 - accuracy: 0.9224 - val_loss: 0.4651 - val_accuracy: 0.8472
# Epoch 2/15
# 475/475 [==============================] - 39s 81ms/step - loss: 0.1321 - accuracy: 0.9594 - val_loss: 0.5949 - val_accuracy: 0.7842
# Epoch 3/15
# 475/475 [==============================] - 40s 85ms/step - loss: 0.1089 - accuracy: 0.9689 - val_loss: 0.4660 - val_accuracy: 0.8421
# Epoch 4/15
# 475/475 [==============================] - 36s 75ms/step - loss: 0.0866 - accuracy: 0.9760 - val_loss: 0.3240 - val_accuracy: 0.8984
# Epoch 5/15
# 475/475 [==============================] - 38s 80ms/step - loss: 0.0697 - accuracy: 0.9805 - val_loss: 0.4893 - val_accuracy: 0.8584
# Epoch 6/15
# 475/475 [==============================] - 36s 76ms/step - loss: 0.0645 - accuracy: 0.9820 - val_loss: 0.2972 - val_accuracy: 0.9101
# Epoch 7/15
# 475/475 [==============================] - 36s 77ms/step - loss: 0.0540 - accuracy: 0.9865 - val_loss: 0.3404 - val_accuracy: 0.9019
# Epoch 8/15
# 475/475 [==============================] - 37s 78ms/step - loss: 0.0502 - accuracy: 0.9879 - val_loss: 0.3584 - val_accuracy: 0.8994
# Epoch 9/15
# 475/475 [==============================] - 36s 75ms/step - loss: 0.0423 - accuracy: 0.9904 - val_loss: 0.5297 - val_accuracy: 0.8536
# Epoch 10/15
# 475/475 [==============================] - 42s 89ms/step - loss: 0.0392 - accuracy: 0.9914 - val_loss: 0.4219 - val_accuracy: 0.8885
# Epoch 11/15
# 475/475 [==============================] - 38s 80ms/step - loss: 0.0352 - accuracy: 0.9920 - val_loss: 0.4801 - val_accuracy: 0.8810
# Epoch 12/15
# 475/475 [==============================] - 36s 77ms/step - loss: 0.0342 - accuracy: 0.9924 - val_loss: 0.3136 - val_accuracy: 0.9134
# Epoch 13/15
# 475/475 [==============================] - 39s 82ms/step - loss: 0.0342 - accuracy: 0.9932 - val_loss: 0.5602 - val_accuracy: 0.8687
# Epoch 14/15
# 475/475 [==============================] - 40s 84ms/step - loss: 0.0273 - accuracy: 0.9949 - val_loss: 0.5471 - val_accuracy: 0.8701
# Epoch 15/15
# 475/475 [==============================] - 36s 76ms/step - loss: 0.0264 - accuracy: 0.9944 - val_loss: 0.3994 - val_accuracy: 0.9085

# %%
test_loss, test_acc = cnn_bilstm_model.evaluate(test_padded, test_data['label'])
print('Test accuracy:', test_acc)
# Out:
# 150/150 [==============================] - 1s 9ms/step - loss: 0.0797 - accuracy: 0.9824
# Test accuracy: 0.9823862314224243

# %%
# Define the LSTM model

input_layer = Input(shape=(max_sequence_length,), dtype='int32')
embedding_layer = Embedding(num_words, embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length)(input_layer)
lstm_layer = LSTM(units=32, dropout=0.5, recurrent_dropout=0.5)(embedding_layer)
lstm_dropout_layer = Dropout(0.5)(lstm_layer)
output_layer = Dense(1, activation='sigmoid', kernel_regularizer=l2(0.01))(lstm_dropout_layer)
lstm_model = Model(inputs=input_layer, outputs=output_layer)

# %%
# Compile the LSTM model
lstm_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
print(lstm_model.summary())
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 38)]              0
#
#  embedding_3 (Embedding)     (None, 38, 100)           1583600
#
#  lstm_3 (LSTM)               (None, 32)                17024
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1,600,657
# Trainable params: 1,600,657
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Train the LSTM model
lstm_model.fit(train_padded, train_data['label'], validation_data=(validation_padded, validation_data['label']), epochs=15, batch_size=32)
# Out:
# Epoch 1/15
# 475/475 [==============================] - 46s 90ms/step - loss: 0.2115 - accuracy: 0.9390 - val_loss: 0.4533 - val_accuracy: 0.8612
# Epoch 2/15
# 475/475 [==============================] - 43s 91ms/step - loss: 0.1134 - accuracy: 0.9702 - val_loss: 0.3177 - val_accuracy: 0.9117
# Epoch 3/15
# 475/475 [==============================] - 41s 87ms/step - loss: 0.0850 - accuracy: 0.9793 - val_loss: 0.2772 - val_accuracy: 0.9264
# Epoch 4/15
# 475/475 [==============================] - 41s 86ms/step - loss: 0.0684 - accuracy: 0.9846 - val_loss: 0.3501 - val_accuracy: 0.9109
# Epoch 5/15
# 475/475 [==============================] - 39s 82ms/step - loss: 0.0570 - accuracy: 0.9897 - val_loss: 0.2728 - val_accuracy: 0.9265
# Epoch 6/15
# 475/475 [==============================] - 39s 82ms/step - loss: 0.0500 - accuracy: 0.9917 - val_loss: 0.2971 - val_accuracy: 0.9251
# Epoch 7/15
# 475/475 [==============================] - 41s 86ms/step - loss: 0.0435 - accuracy: 0.9927 - val_loss: 0.2468 - val_accuracy: 0.9417
# Epoch 8/15
# 475/475 [==============================] - 40s 85ms/step - loss: 0.0412 - accuracy: 0.9941 - val_loss: 0.2731 - val_accuracy: 0.9362
# Epoch 9/15
# 475/475 [==============================] - 40s 84ms/step - loss: 0.0375 - accuracy: 0.9942 - val_loss: 0.3113 - val_accuracy: 0.9216
# Epoch 10/15
# 475/475 [==============================] - 39s 82ms/step - loss: 0.0304 - accuracy: 0.9974 - val_loss: 0.5193 - val_accuracy: 0.8987
# Epoch 11/15
# 475/475 [==============================] - 39s 82ms/step - loss: 0.0309 - accuracy: 0.9965 - val_loss: 0.3349 - val_accuracy: 0.9209
# Epoch 12/15
# 475/475 [==============================] - 41s 86ms/step - loss: 0.0300 - accuracy: 0.9970 - val_loss: 0.2934 - val_accuracy: 0.9362
# Epoch 13/15
# 475/475 [==============================] - 40s 84ms/step - loss: 0.0284 - accuracy: 0.9972 - val_loss: 0.3661 - val_accuracy: 0.9297
# Epoch 14/15
# 475/475 [==============================] - 40s 84ms/step - loss: 0.0251 - accuracy: 0.9986 - val_loss: 0.2959 - val_accuracy: 0.9372
# Epoch 15/15
# 475/475 [==============================] - 40s 84ms/step - loss: 0.0253 - accuracy: 0.9980 - val_loss: 0.3429 - val_accuracy: 0.9286

# %%
test_loss, test_acc = lstm_model.evaluate(test_padded, test_data['label'])
print('Test accuracy:', test_acc)
# Out:
# 150/150 [==============================] - 1s 8ms/step - loss: 0.0919 - accuracy: 0.9799
# Test accuracy: 0.9798700213432312

# %%
#Define Bilstm model
input_layer = Input(shape=(max_sequence_length,), dtype='int32')
embedding_layer = Embedding(num_words, embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length)(input_layer)
lstm_layer = Bidirectional(LSTM(units=32, dropout=0.5, recurrent_dropout=0.5))(embedding_layer)
lstm_dropout_layer = Dropout(0.5)(lstm_layer)
output_layer = Dense(1, activation='sigmoid', kernel_regularizer=l2(0.01))(lstm_dropout_layer)
bilstm_model = Model(inputs=input_layer, outputs=output_layer)

# %%
bilstm_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
print(bilstm_model.summary())
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 38)]              0
#
#  embedding_4 (Embedding)     (None, 38, 100)           1583600
#
#  bidirectional_2 (Bidirectio  (None, 64)               34048
#  nal)
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 1,617,713
# Trainable params: 1,617,713
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
bilstm_model.fit(train_padded, train_data['label'], validation_data=(validation_padded, validation_data['label']), epochs=15, batch_size=32)
# Out:
# Epoch 1/15
# 475/475 [==============================] - 74s 140ms/step - loss: 0.1900 - accuracy: 0.9400 - val_loss: 0.5137 - val_accuracy: 0.8384
# Epoch 2/15
# 475/475 [==============================] - 65s 138ms/step - loss: 0.0934 - accuracy: 0.9750 - val_loss: 0.4135 - val_accuracy: 0.8733
# Epoch 3/15
# 475/475 [==============================] - 65s 137ms/step - loss: 0.0656 - accuracy: 0.9852 - val_loss: 0.2130 - val_accuracy: 0.9372
# Epoch 4/15
# 475/475 [==============================] - 67s 141ms/step - loss: 0.0482 - accuracy: 0.9905 - val_loss: 0.4325 - val_accuracy: 0.8839
# Epoch 5/15
# 475/475 [==============================] - 65s 138ms/step - loss: 0.0384 - accuracy: 0.9924 - val_loss: 0.4451 - val_accuracy: 0.8932
# Epoch 6/15
# 475/475 [==============================] - 65s 137ms/step - loss: 0.0312 - accuracy: 0.9943 - val_loss: 0.4992 - val_accuracy: 0.8771
# Epoch 7/15
# 475/475 [==============================] - 64s 136ms/step - loss: 0.0276 - accuracy: 0.9964 - val_loss: 0.5148 - val_accuracy: 0.8867
# Epoch 8/15
# 475/475 [==============================] - 65s 137ms/step - loss: 0.0239 - accuracy: 0.9968 - val_loss: 0.4261 - val_accuracy: 0.9041
# Epoch 9/15
# 475/475 [==============================] - 67s 140ms/step - loss: 0.0222 - accuracy: 0.9973 - val_loss: 0.3021 - val_accuracy: 0.9297
# Epoch 10/15
# 475/475 [==============================] - 66s 138ms/step - loss: 0.0198 - accuracy: 0.9980 - val_loss: 0.4622 - val_accuracy: 0.8962
# Epoch 11/15
# 475/475 [==============================] - 63s 133ms/step - loss: 0.0181 - accuracy: 0.9986 - val_loss: 0.4357 - val_accuracy: 0.9090
# Epoch 12/15
# 475/475 [==============================] - 66s 139ms/step - loss: 0.0180 - accuracy: 0.9981 - val_loss: 0.3721 - val_accuracy: 0.9055
# Epoch 13/15
# 475/475 [==============================] - 65s 138ms/step - loss: 0.0161 - accuracy: 0.9990 - val_loss: 0.5393 - val_accuracy: 0.8868
# Epoch 14/15
# 475/475 [==============================] - 67s 142ms/step - loss: 0.0141 - accuracy: 0.9993 - val_loss: 0.5355 - val_accuracy: 0.8953
# Epoch 15/15
# 475/475 [==============================] - 65s 138ms/step - loss: 0.0139 - accuracy: 0.9992 - val_loss: 0.3593 - val_accuracy: 0.9220

# %%
test_loss, test_acc = bilstm_model.evaluate(test_padded, test_data['label'])
print('Test accuracy:', test_acc)
# Out:
# 150/150 [==============================] - 2s 13ms/step - loss: 0.0856 - accuracy: 0.9790
# Test accuracy: 0.9790312647819519
