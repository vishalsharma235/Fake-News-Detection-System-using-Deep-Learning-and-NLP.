# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

trueData = '/content/drive/MyDrive/Btech_project/True.csv'
fakeData = '/content/drive/MyDrive/Btech_project/Fake.csv'

true_Df = pd.read_csv(trueData)
fake_Df = pd.read_csv(fakeData)

# %%
display(fake_Df)
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 0      Donald Trump just couldn t wish all Americans ...         News
# 1      House Intelligence Committee Chairman Devin Nu...         News
# 2      On Friday, it was revealed that former Milwauk...         News
# 3      On Christmas day, Donald Trump announced that ...         News
# 4      Pope Francis used his annual Christmas Day mes...         News
# ...                                                  ...          ...
# 23476  21st Century Wire says As 21WIRE reported earl...  Middle-east
# 23477  21st Century Wire says It s a familiar theme. ...  Middle-east
# 23478  Patrick Henningsen  21st Century WireRemember ...  Middle-east
# 23479  21st Century Wire says Al Jazeera America will...  Middle-east
# 23480  21st Century Wire says As 21WIRE predicted in ...  Middle-east
#
#                     date
# 0      December 31, 2017
# 1      December 31, 2017
# 2      December 30, 2017
# 3      December 29, 2017
# 4      December 25, 2017
# ...                  ...
# 23476   January 16, 2016
# 23477   January 16, 2016
# 23478   January 15, 2016
# 23479   January 14, 2016
# 23480   January 12, 2016
#
# [23481 rows x 4 columns]

# %%
display(true_Df)
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...     worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...     worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...     worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...     worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...     worldnews
#
#                      date
# 0      December 31, 2017
# 1      December 29, 2017
# 2      December 31, 2017
# 3      December 30, 2017
# 4      December 29, 2017
# ...                   ...
# 21412    August 22, 2017
# 21413    August 22, 2017
# 21414    August 22, 2017
# 21415    August 22, 2017
# 21416    August 22, 2017
#
# [21417 rows x 4 columns]

# %% [markdown]
# ***WordCloud for Real News***

# %%
from wordcloud import WordCloud
import seaborn as sns
import matplotlib.pyplot as plt

real_Titles = true_Df.title
real_allWords = ' '.join(real_Titles)
real_WordCloud = WordCloud(background_color='Black',
    width= 800, height= 500,
    max_font_size = 180,
    collocations = False).generate(real_allWords)

plt.figure(figsize=(10,7))
plt.imshow(real_WordCloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ***WordCloud for fake news***

# %%
fake_Titles = fake_Df.title
fake_allWords = ' '.join(fake_Titles)
fake_WordCloud = WordCloud(background_color='Black',
    width= 800, height= 500,
    max_font_size = 180,
    collocations = False).generate(fake_allWords)

plt.figure(figsize=(10,7))
plt.imshow(fake_WordCloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ***Data Visualization***

# %%
sns.countplot(y="subject", palette="coolwarm", data=true_Df).set_title('Subject Distribution for true news')
plt.show()

# %%
sns.countplot(y="subject", palette="coolwarm", data=fake_Df).set_title('Subject Distribution for fake news')
plt.show()

# %% [markdown]
# ***Data Preprocessing***

# %%
true_Df['label'] = 1
fake_Df['label'] = 0


df = pd.concat([true_Df, fake_Df])
display(df)
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 23476  21st Century Wire says As 21WIRE reported earl...   Middle-east
# 23477  21st Century Wire says It s a familiar theme. ...   Middle-east
# 23478  Patrick Henningsen  21st Century WireRemember ...   Middle-east
# 23479  21st Century Wire says Al Jazeera America will...   Middle-east
# 23480  21st Century Wire says As 21WIRE predicted in ...   Middle-east
#
#                      date  label
# 0      December 31, 2017       1
# 1      December 29, 2017       1
# 2      December 31, 2017       1
# 3      December 30, 2017       1
# 4      December 29, 2017       1
# ...                   ...    ...
# 23476    January 16, 2016      0
# 23477    January 16, 2016      0
# 23478    January 15, 2016      0
# 23479    January 14, 2016      0
# 23480    January 12, 2016      0
#
# [44898 rows x 5 columns]

# %% [markdown]
# ***Inspecting Length of News titles***

# %%
titles = [text for text in df.title]

max_len = 0
titles_len = []
for title in titles:
    titles_len.append(len(title.split()))
    max_len = max(len(title.split()), max_len)

print('Number of titles:', len(titles))
print('Max length of the titles:', max_len)
print('Mean length of the titles:', np.mean(titles_len))
# Out:
# Number of titles: 44898
# Max length of the titles: 42
# Mean length of the titles: 12.453472315025168

# %% [markdown]
# ***Inspecting length of News statements***

# %%
texts = [text for text in df.text]

max_len = 0
texts_len = []
for text in texts:
    texts_len.append(len(text.split()))
    max_len = max(len(text.split()), max_len)

print('Mean length of the texts:', np.mean(texts_len))
# Out:
# Mean length of the texts: 405.28228428883244

# %% [markdown]
# ***Purifying and shuffling the dataframe***

# %%
from sklearn.utils import shuffle

# Purify
df = df.iloc[:,[0, -1]]

# Shuffle
df = shuffle(df).reset_index(drop=True)

display(df)
# Out:
#                                                    title  label
# 0      Merkel says fight against terrorism no excuse ...      1
# 1       Trump Would Give Ivanka SICK And DISGUSTING A...      0
# 2      Northern Ireland's DUP says talks with UK gove...      1
# 3      U.S. Labor Secretary says fiduciary rule to ta...      1
# 4      Squeaky-clean Zurich's trash department probed...      1
# ...                                                  ...    ...
# 44893  Brazil poll shows Temer approval plummets on n...      1
# 44894  SIX FACTS ABOUT Sheriff Joe Arpaio Case That W...      0
# 44895  Comey to be pressed on whether Trump interfere...      1
# 44896             Gerald Celente: Top 10 Trends for 2017      0
# 44897  YES! SHERIFF CALLS OUT HILLARY CLINTON For Bla...      0
#
# [44898 rows x 2 columns]

# %% [markdown]
# ***Splitting data into training, validation and testing.***

# %%
train_validate_df = df.sample(frac = 0.8)
test_df = df.drop(train_validate_df.index)

train_df = train_validate_df.sample(frac = 0.8)
validation_df = train_validate_df.drop(train_df.index)

# Reset Index
train_df = train_df.reset_index(drop=True)
validation_df = validation_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

print('train_dataset size:', train_df.shape)
print('validation_dataset size:', validation_df.shape)
print('testing_dataset size:', test_df.shape)
# Out:
# train_dataset size: (28734, 2)
# validation_dataset size: (7184, 2)
# testing_dataset size: (8980, 2)

# %%
train_imbalanced = 1/10
val_imbalanced = 1/10
test_imbalanced = 1/10

train_true = train_df[train_df['label'] == 1]
train_fake = train_df[train_df['label'] == 0]
train_fake = train_fake.iloc[:round(len(train_fake)*train_imbalanced),:]
train_true_len = len(train_true)
train_fake_len = len(train_fake)
train_df = pd.concat([train_true, train_fake])
train_df = shuffle(train_df).reset_index(drop=True)

val_true = validation_df[validation_df['label'] == 1]
val_fake = validation_df[validation_df['label'] == 0]
val_fake = val_fake.iloc[:round(len(val_fake)*val_imbalanced),:]
val_true_len = len(val_true)
val_fake_len = len(val_fake)
val_df = pd.concat([val_true, val_fake])
val_df = shuffle(val_df).reset_index(drop=True)

test_true = test_df[test_df['label'] == 1]
test_fake = test_df[test_df['label'] == 0]
test_fake = test_fake.iloc[:round(len(test_fake)*test_imbalanced),:]
test_true_len = len(test_true)
test_fake_len = len(test_fake)
test_df = pd.concat([test_true, test_fake])
test_df = shuffle(test_df).reset_index(drop=True)

len_df = pd.DataFrame({'ind': ['Train', 'Validation', 'Test'], 'True': [train_true_len, val_true_len, test_true_len], 'Fake': [train_fake_len, val_fake_len, test_fake_len]})
len_df.set_index('ind', inplace=True)
len_df.index.name = None

len_df
# Out:
#              True  Fake
# Train       13701  1503
# Validation   3409   378
# Test         4307   467

# %%
train_df.to_csv('train.tsv', sep='\t', index=False)
validation_df.to_csv('val.tsv', sep='\t', index=False)
test_df.to_csv('test.tsv', sep='\t', index=False)

# %%
df = pd.concat([train_df, validation_df, test_df])
df.to_csv('non.csv',index=False)

# %%
import nltk
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
#def tokenize(column):
  #tokens = nltk.word_tokenize(column)
  #return [w for w in tokens if w.isalpha()]

# %%
#df['tokenized'] = df.apply(lambda x: tokenize(x['title']), axis=1)
#df[['tokenized']].head()

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
df = pd.read_csv('non.csv')

def lemmatize_word(word):
    return lemmatizer.lemmatize(word, pos='v')

df['lemmatized_column'] = df['title'].apply(lambda x: ' '.join([lemmatize_word(word) for word in x.split()]))

df.to_csv('lemmatized.csv', index=False)

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

# %%
print(stop_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'from', 'subject', 're', 'edu', 'use']

# %%
import gensim

# %%
def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3 and token not in stop_words:
            result.append(token)
            
    return result

# %%
df = pd.read_csv('lemmatized.csv')
df['clean'] = df['lemmatized_column'].apply(preprocess)
df
# Out:
#                                                    title  label  \
# 0      Catalan leader's farmhouse pact to make last s...      1
# 1      Trump chooses fundraiser Scaramucci for ambass...      1
# 2      Obama to seek $755 million for cancer 'moonsho...      1
# 3      Scottish isle a world away from fireworks of n...      1
# 4      LEFTIST PROTESTOR CUTS ELECTRICITY To Trump Ra...      0
# ...                                                  ...    ...
# 27157  Uganda postpones bill to extend Museveni's rul...      1
# 27158  Ending Iran nuclear deal would worsen North Ko...      1
# 27159  Trump to top U.S. diplomat: Don't bother talki...      1
# 27160  Exclusive: Trump says U.S. wants fair treatmen...      1
# 27161  U.S. service member killed in Iraq IED blast: ...      1
#
#                                        lemmatized_column  \
# 0      Catalan leader's farmhouse pact to make last s...
# 1      Trump choose fundraiser Scaramucci for ambassa...
# 2      Obama to seek $755 million for cancer 'moonsho...
# 3      Scottish isle a world away from fireworks of n...
# 4      LEFTIST PROTESTOR CUTS ELECTRICITY To Trump Ra...
# ...                                                  ...
# 27157  Uganda postpone bill to extend Museveni's rule...
# 27158  Ending Iran nuclear deal would worsen North Ko...
# 27159  Trump to top U.S. diplomat: Don't bother talk ...
# 27160  Exclusive: Trump say U.S. want fair treatment ...
# 27161  U.S. service member kill in Iraq IED blast: Pe...
#
#                                                    clean
# 0      [catalan, leader, farmhouse, pact, stand, brus...
# 1      [trump, choose, fundraiser, scaramucci, ambass...
# 2      [obama, seek, million, cancer, moonshot, white...
# 3      [scottish, isle, world, away, fireworks, nativ...
# 4      [leftist, protestor, cuts, electricity, trump,...
# ...                                                  ...
# 27157  [uganda, postpone, extend, museveni, rule, pro...
# 27158  [ending, iran, nuclear, deal, worsen, north, k...
# 27159      [trump, diplomat, bother, talk, north, korea]
# 27160  [exclusive, trump, want, fair, treatment, clim...
# 27161     [service, member, kill, iraq, blast, pentagon]
#
# [27162 rows x 4 columns]

# %%
list_of_words = []
for i in df.clean:
    for j in i:
        list_of_words.append(j)

total_words = len(list(set(list_of_words)))
total_words
# Out:
# 14629

# %%
pip list | grep tensorflow
# Out:
# tensorflow                    2.12.0
# tensorflow-datasets           4.8.3
# tensorflow-estimator          2.12.0
# tensorflow-gcs-config         2.12.0
# tensorflow-hub                0.13.0
# tensorflow-io-gcs-filesystem  0.32.0
# tensorflow-metadata           1.13.1
# tensorflow-probability        0.19.0

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Embedding, Input, LSTM, Conv1D, MaxPool1D, Bidirectional, Dropout, BatchNormalization
import numpy as np

# %%
# Load the data
train_data = pd.read_csv('train.tsv', delimiter='\t')
test_data = pd.read_csv('test.tsv', delimiter='\t')
validation_data = pd.read_csv('val.tsv', delimiter='\t')

# %%
# Creating A Tokenizer To Tokenize The Words And Create Sequences Of Tokenized Words
tokenizer = Tokenizer(num_words = total_words)
tokenizer.fit_on_texts(train_df['title'])

# Convert the texts to sequences
train_sequences = tokenizer.texts_to_sequences(train_data['title'])
validation_sequences = tokenizer.texts_to_sequences(validation_data['title'])
test_sequences = tokenizer.texts_to_sequences(test_data['title'])

# %%
# Get the maximum sequence length
max_sequence_length = max(len(seq) for seq in train_sequences)
max_sequence_length
# Out:
# 38

# %%
# Pad the sequences
train_padded = pad_sequences(train_sequences, maxlen=max_sequence_length, padding='post', truncating='post')
test_padded = pad_sequences(test_sequences, maxlen=max_sequence_length, padding='post', truncating='post')
validation_padded = pad_sequences(validation_sequences, maxlen=max_sequence_length, padding='post', truncating='post')

# %%
# import numpy as np
# import fasttext

# # Download FastText embeddings
# fasttext_model = gensim.models.KeyedVectors.load_word2vec_format('/content/drive/MyDrive/Btech_project/cc.en.300.bin', binary=False,encoding='None')

# # Load Glove embeddings
# glove_embeddings = {}
# with open('/content/drive/MyDrive/Btech_project/glove.6B.100d.txt', 'rb') as f:
#     for line in f:
#         values = line.decode('utf-8').split()
#         word = values[0]
#         coefs = np.asarray(values[1:], dtype='float32')
#         glove_embeddings[word] = coefs

# # Create the embedding matrix
# word_index = tokenizer.word_index
# num_words = len(word_index) + 1
# embedding_matrix = np.zeros((num_words, embedding_dim))
# for word, i in word_index.items():
#     glove_embedding_vector = glove_embeddings.get(word)
#     fasttext_embedding_vector = fasttext_model[word] if word in fasttext_model else None
#     if glove_embedding_vector is not None:
#         embedding_matrix[i] = np.concatenate([glove_embedding_vector, fasttext_embedding_vector])
#     elif fasttext_embedding_vector is not None:
#         embedding_matrix[i] = fasttext_embedding_vector

# %%
pip install fasttext
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fasttext
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pybind11>=2.2
#   Using cached pybind11-2.10.4-py3-none-any.whl (222 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext) (67.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fasttext) (1.22.4)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4393329 sha256=ada6d63c784fd844dad2c0c4c9f983fd35260ec92ccd702e9198dccda05508a9
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.2 pybind11-2.10.4

# %%
# Define the embedding dimension
embedding_dim = 300

# Load the FastText model
import fasttext
ft = fasttext.load_model('/content/drive/MyDrive/Btech_project/cc.en.300.bin')

# Create the embedding matrix
word_index = tokenizer.word_index
num_words = len(word_index) + 1
embedding_matrix = np.zeros((num_words, embedding_dim))
for word, i in word_index.items():
    embedding_vector = ft.get_word_vector(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, Input, Dense, Flatten, Conv1D, MaxPooling1D, LSTM, Bidirectional, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Define the LSTM model

from keras.regularizers import l2
input_layer = Input(shape=(max_sequence_length,), dtype='int32')
embedding_layer = Embedding(num_words, embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length)(input_layer)
lstm_layer = LSTM(units=32, dropout=0.5, recurrent_dropout=0.5)(embedding_layer)
lstm_dropout_layer = Dropout(0.5)(lstm_layer)
output_layer = Dense(1, activation='sigmoid', kernel_regularizer=l2(0.01))(lstm_dropout_layer)
lstm_model = Model(inputs=input_layer, outputs=output_layer)

# %%
# Compile the LSTM model
lstm_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
print(lstm_model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 38)]              0
#
#  embedding (Embedding)       (None, 38, 300)           4732500
#
#  lstm (LSTM)                 (None, 32)                42624
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 4,775,157
# Trainable params: 4,775,157
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Train the LSTM model
lstm_model.fit(train_padded, train_data['label'], validation_data=(validation_padded, validation_data['label']), epochs=15, batch_size=32)
# Out:
# Epoch 1/15
# 476/476 [==============================] - 97s 196ms/step - loss: 0.2045 - accuracy: 0.9442 - val_loss: 0.2923 - val_accuracy: 0.9310
# Epoch 2/15
# 476/476 [==============================] - 75s 158ms/step - loss: 0.0710 - accuracy: 0.9862 - val_loss: 0.3038 - val_accuracy: 0.9169
# Epoch 3/15
# 476/476 [==============================] - 76s 159ms/step - loss: 0.0426 - accuracy: 0.9947 - val_loss: 0.3907 - val_accuracy: 0.9101
# Epoch 4/15
# 476/476 [==============================] - 80s 167ms/step - loss: 0.0380 - accuracy: 0.9950 - val_loss: 0.3293 - val_accuracy: 0.9300
# Epoch 5/15
# 476/476 [==============================] - 73s 154ms/step - loss: 0.0271 - accuracy: 0.9976 - val_loss: 0.5003 - val_accuracy: 0.9033
# Epoch 6/15
# 476/476 [==============================] - 73s 154ms/step - loss: 0.0252 - accuracy: 0.9982 - val_loss: 0.2927 - val_accuracy: 0.9226
# Epoch 7/15
# 476/476 [==============================] - 73s 154ms/step - loss: 0.0283 - accuracy: 0.9969 - val_loss: 0.4373 - val_accuracy: 0.9127
# Epoch 8/15
# 476/476 [==============================] - 74s 156ms/step - loss: 0.0235 - accuracy: 0.9985 - val_loss: 0.4360 - val_accuracy: 0.9159
# Epoch 9/15
# 476/476 [==============================] - 78s 164ms/step - loss: 0.0194 - accuracy: 0.9993 - val_loss: 0.4582 - val_accuracy: 0.9154
# Epoch 10/15
# 476/476 [==============================] - 74s 156ms/step - loss: 0.0203 - accuracy: 0.9988 - val_loss: 0.4753 - val_accuracy: 0.9124
# Epoch 11/15
# 476/476 [==============================] - 74s 155ms/step - loss: 0.0220 - accuracy: 0.9982 - val_loss: 0.4631 - val_accuracy: 0.9129
# Epoch 12/15
# 476/476 [==============================] - 74s 155ms/step - loss: 0.0184 - accuracy: 0.9990 - val_loss: 0.4411 - val_accuracy: 0.9211
# Epoch 13/15
# 476/476 [==============================] - 75s 157ms/step - loss: 0.0157 - accuracy: 0.9997 - val_loss: 0.4293 - val_accuracy: 0.9225
# Epoch 14/15
# 476/476 [==============================] - 77s 161ms/step - loss: 0.0152 - accuracy: 0.9999 - val_loss: 0.4927 - val_accuracy: 0.9149
# Epoch 15/15
# 476/476 [==============================] - 73s 154ms/step - loss: 0.0143 - accuracy: 0.9999 - val_loss: 0.5791 - val_accuracy: 0.9045

# %%
test_loss, test_acc = lstm_model.evaluate(test_padded, test_data['label'])
print('Test accuracy:', test_acc)
# Out:
# 150/150 [==============================] - 2s 10ms/step - loss: 0.1469 - accuracy: 0.9755
# Test accuracy: 0.9754922389984131

# %%
#Define Bilstm model
input_layer = Input(shape=(max_sequence_length,), dtype='int32')
embedding_layer = Embedding(num_words, embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length)(input_layer)
lstm_layer = Bidirectional(LSTM(units=32, dropout=0.5, recurrent_dropout=0.5))(embedding_layer)
lstm_dropout_layer = Dropout(0.5)(lstm_layer)
output_layer = Dense(1, activation='sigmoid', kernel_regularizer=l2(0.01))(lstm_dropout_layer)
bilstm_model = Model(inputs=input_layer, outputs=output_layer)

# %%
bilstm_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
print(bilstm_model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 38)]              0
#
#  embedding_1 (Embedding)     (None, 38, 300)           4732500
#
#  bidirectional (Bidirectiona  (None, 64)               85248
#  l)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4,817,813
# Trainable params: 4,817,813
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
bilstm_model.fit(train_padded, train_data['label'], validation_data=(validation_padded, validation_data['label']), epochs=15, batch_size=32)
# Out:
# Epoch 1/15
# 476/476 [==============================] - 118s 234ms/step - loss: 0.1668 - accuracy: 0.9524 - val_loss: 0.3624 - val_accuracy: 0.8963
# Epoch 2/15
# 476/476 [==============================] - 110s 231ms/step - loss: 0.0469 - accuracy: 0.9902 - val_loss: 0.3206 - val_accuracy: 0.9122
# Epoch 3/15
# 476/476 [==============================] - 110s 232ms/step - loss: 0.0295 - accuracy: 0.9967 - val_loss: 0.3535 - val_accuracy: 0.9094
# Epoch 4/15
# 476/476 [==============================] - 111s 234ms/step - loss: 0.0216 - accuracy: 0.9989 - val_loss: 0.3850 - val_accuracy: 0.9034
# Epoch 5/15
# 476/476 [==============================] - 116s 243ms/step - loss: 0.0184 - accuracy: 0.9995 - val_loss: 0.4528 - val_accuracy: 0.8914
# Epoch 6/15
# 476/476 [==============================] - 110s 232ms/step - loss: 0.0178 - accuracy: 0.9996 - val_loss: 0.4171 - val_accuracy: 0.8918
# Epoch 7/15
# 476/476 [==============================] - 111s 232ms/step - loss: 0.0182 - accuracy: 0.9992 - val_loss: 0.4353 - val_accuracy: 0.8959
# Epoch 8/15
# 476/476 [==============================] - 111s 234ms/step - loss: 0.0153 - accuracy: 0.9999 - val_loss: 0.4506 - val_accuracy: 0.8751
# Epoch 9/15
# 476/476 [==============================] - 118s 248ms/step - loss: 0.0148 - accuracy: 0.9999 - val_loss: 0.4791 - val_accuracy: 0.8785
# Epoch 10/15
# 476/476 [==============================] - 120s 253ms/step - loss: 0.0144 - accuracy: 0.9997 - val_loss: 0.4929 - val_accuracy: 0.8761
# Epoch 11/15
# 476/476 [==============================] - 131s 275ms/step - loss: 0.0145 - accuracy: 0.9997 - val_loss: 0.5027 - val_accuracy: 0.8918
# Epoch 12/15
# 476/476 [==============================] - 132s 277ms/step - loss: 0.0145 - accuracy: 0.9993 - val_loss: 0.4320 - val_accuracy: 0.9030
# Epoch 13/15
# 476/476 [==============================] - 130s 273ms/step - loss: 0.0113 - accuracy: 0.9997 - val_loss: 0.5091 - val_accuracy: 0.8963
# Epoch 14/15
# 476/476 [==============================] - 133s 280ms/step - loss: 0.0107 - accuracy: 0.9997 - val_loss: 0.4456 - val_accuracy: 0.9069
# Epoch 15/15
# 476/476 [==============================] - 131s 275ms/step - loss: 0.0106 - accuracy: 0.9998 - val_loss: 0.4788 - val_accuracy: 0.8910

# %%
test_loss, test_acc = bilstm_model.evaluate(test_padded, test_data['label'])
print('Test accuracy:', test_acc)
# Out:
# 150/150 [==============================] - 3s 18ms/step - loss: 0.1247 - accuracy: 0.9709
# Test accuracy: 0.9708839654922485

# %%
#Define the CNN-BiLSTM model


input_layer = Input(shape=(max_sequence_length,), dtype='int32')
embedding_layer = Embedding(num_words, embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length)(input_layer)
embedding_dropout_layer = Dropout(0.5)(embedding_layer)
conv_layer = Conv1D(filters=16, kernel_size=3, padding='same', activation='relu')(embedding_dropout_layer)
conv_dropout_layer = Dropout(0.5)(conv_layer)
pool_layer = MaxPooling1D(pool_size=2)(conv_dropout_layer)
bilstm_layer = Bidirectional(LSTM(units=32, dropout=0.5, recurrent_dropout=0.5))(pool_layer)
bilstm_dropout_layer = Dropout(0.5)(bilstm_layer)
output_layer = Dense(1, activation='sigmoid', kernel_regularizer=l2(0.01))(bilstm_dropout_layer)
cnn_bilstm_model = Model(inputs=input_layer, outputs=output_layer)

# %%
print(cnn_bilstm_model.summary())
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 38)]              0
#
#  embedding_2 (Embedding)     (None, 38, 300)           4732500
#
#  dropout_2 (Dropout)         (None, 38, 300)           0
#
#  conv1d (Conv1D)             (None, 38, 16)            14416
#
#  dropout_3 (Dropout)         (None, 38, 16)            0
#
#  max_pooling1d (MaxPooling1D  (None, 19, 16)           0
#  )
#
#  bidirectional_1 (Bidirectio  (None, 64)               12544
#  nal)
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4,759,525
# Trainable params: 4,759,525
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Compile the CNN-BiLSTM model
cnn_bilstm_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
#Train the CNN-BiLSTM model
cnn_bilstm_model.fit(train_padded, train_data['label'], validation_data=(validation_padded, validation_data['label']), epochs=15, batch_size=32)
# Out:
# Epoch 1/15
# 476/476 [==============================] - 71s 134ms/step - loss: 0.1945 - accuracy: 0.9390 - val_loss: 0.3349 - val_accuracy: 0.8999
# Epoch 2/15
# 476/476 [==============================] - 60s 127ms/step - loss: 0.0626 - accuracy: 0.9854 - val_loss: 0.2808 - val_accuracy: 0.9227
# Epoch 3/15
# 476/476 [==============================] - 61s 128ms/step - loss: 0.0395 - accuracy: 0.9922 - val_loss: 0.2719 - val_accuracy: 0.9285
# Epoch 4/15
# 476/476 [==============================] - 61s 128ms/step - loss: 0.0273 - accuracy: 0.9957 - val_loss: 0.3351 - val_accuracy: 0.9202
# Epoch 5/15
# 476/476 [==============================] - 62s 129ms/step - loss: 0.0221 - accuracy: 0.9974 - val_loss: 0.4201 - val_accuracy: 0.9127
# Epoch 6/15
# 476/476 [==============================] - 60s 126ms/step - loss: 0.0188 - accuracy: 0.9974 - val_loss: 0.2696 - val_accuracy: 0.9410
# Epoch 7/15
# 476/476 [==============================] - 61s 128ms/step - loss: 0.0161 - accuracy: 0.9986 - val_loss: 0.4075 - val_accuracy: 0.9182
# Epoch 8/15
# 476/476 [==============================] - 61s 128ms/step - loss: 0.0156 - accuracy: 0.9985 - val_loss: 0.5096 - val_accuracy: 0.8985
# Epoch 9/15
# 476/476 [==============================] - 62s 130ms/step - loss: 0.0148 - accuracy: 0.9988 - val_loss: 0.3885 - val_accuracy: 0.9169
# Epoch 10/15
# 476/476 [==============================] - 60s 127ms/step - loss: 0.0138 - accuracy: 0.9988 - val_loss: 0.4380 - val_accuracy: 0.9130
# Epoch 11/15
# 476/476 [==============================] - 60s 126ms/step - loss: 0.0130 - accuracy: 0.9991 - val_loss: 0.4534 - val_accuracy: 0.9035
# Epoch 12/15
# 476/476 [==============================] - 59s 125ms/step - loss: 0.0115 - accuracy: 0.9999 - val_loss: 0.3164 - val_accuracy: 0.9365
# Epoch 13/15
# 476/476 [==============================] - 66s 138ms/step - loss: 0.0126 - accuracy: 0.9991 - val_loss: 0.5653 - val_accuracy: 0.8808
# Epoch 14/15
# 476/476 [==============================] - 59s 124ms/step - loss: 0.0120 - accuracy: 0.9991 - val_loss: 0.5700 - val_accuracy: 0.8772
# Epoch 15/15
# 476/476 [==============================] - 58s 122ms/step - loss: 0.0108 - accuracy: 0.9995 - val_loss: 0.4920 - val_accuracy: 0.8996

# %%
test_loss, test_acc = cnn_bilstm_model.evaluate(test_padded, test_data['label'])
print('Test accuracy:', test_acc)
# Out:
# 150/150 [==============================] - 1s 8ms/step - loss: 0.1232 - accuracy: 0.9740
# Test accuracy: 0.9740259647369385
