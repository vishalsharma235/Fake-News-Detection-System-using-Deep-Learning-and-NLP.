# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

trueData = '/content/drive/MyDrive/Btech_project/True.csv'
fakeData = '/content/drive/MyDrive/Btech_project/Fake.csv'

true_Df = pd.read_csv(trueData)
fake_Df = pd.read_csv(fakeData)

# %%
display(fake_Df)
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 0      Donald Trump just couldn t wish all Americans ...         News
# 1      House Intelligence Committee Chairman Devin Nu...         News
# 2      On Friday, it was revealed that former Milwauk...         News
# 3      On Christmas day, Donald Trump announced that ...         News
# 4      Pope Francis used his annual Christmas Day mes...         News
# ...                                                  ...          ...
# 23476  21st Century Wire says As 21WIRE reported earl...  Middle-east
# 23477  21st Century Wire says It s a familiar theme. ...  Middle-east
# 23478  Patrick Henningsen  21st Century WireRemember ...  Middle-east
# 23479  21st Century Wire says Al Jazeera America will...  Middle-east
# 23480  21st Century Wire says As 21WIRE predicted in ...  Middle-east
#
#                     date
# 0      December 31, 2017
# 1      December 31, 2017
# 2      December 30, 2017
# 3      December 29, 2017
# 4      December 25, 2017
# ...                  ...
# 23476   January 16, 2016
# 23477   January 16, 2016
# 23478   January 15, 2016
# 23479   January 14, 2016
# 23480   January 12, 2016
#
# [23481 rows x 4 columns]

# %%
display(true_Df)
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...     worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...     worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...     worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...     worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...     worldnews
#
#                      date
# 0      December 31, 2017
# 1      December 29, 2017
# 2      December 31, 2017
# 3      December 30, 2017
# 4      December 29, 2017
# ...                   ...
# 21412    August 22, 2017
# 21413    August 22, 2017
# 21414    August 22, 2017
# 21415    August 22, 2017
# 21416    August 22, 2017
#
# [21417 rows x 4 columns]

# %% [markdown]
# ***WordCloud for Real News***

# %%
from wordcloud import WordCloud
import seaborn as sns
import matplotlib.pyplot as plt

real_Titles = true_Df.title
real_allWords = ' '.join(real_Titles)
real_WordCloud = WordCloud(background_color='Black',
    width= 800, height= 500,
    max_font_size = 180,
    collocations = False).generate(real_allWords)

plt.figure(figsize=(10,7))
plt.imshow(real_WordCloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ***WordCloud for fake news***

# %%
fake_Titles = fake_Df.title
fake_allWords = ' '.join(fake_Titles)
fake_WordCloud = WordCloud(background_color='Black',
    width= 800, height= 500,
    max_font_size = 180,
    collocations = False).generate(fake_allWords)

plt.figure(figsize=(10,7))
plt.imshow(fake_WordCloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ***Data Visualization***

# %%
sns.countplot(y="subject", palette="coolwarm", data=true_Df).set_title('Subject Distribution for true news')
plt.show()

# %%
sns.countplot(y="subject", palette="coolwarm", data=fake_Df).set_title('Subject Distribution for fake news')
plt.show()

# %% [markdown]
# ***Data Preprocessing***

# %%
true_Df['label'] = 1
fake_Df['label'] = 0


df = pd.concat([true_Df, fake_Df])
display(df)
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 23476  21st Century Wire says As 21WIRE reported earl...   Middle-east
# 23477  21st Century Wire says It s a familiar theme. ...   Middle-east
# 23478  Patrick Henningsen  21st Century WireRemember ...   Middle-east
# 23479  21st Century Wire says Al Jazeera America will...   Middle-east
# 23480  21st Century Wire says As 21WIRE predicted in ...   Middle-east
#
#                      date  label
# 0      December 31, 2017       1
# 1      December 29, 2017       1
# 2      December 31, 2017       1
# 3      December 30, 2017       1
# 4      December 29, 2017       1
# ...                   ...    ...
# 23476    January 16, 2016      0
# 23477    January 16, 2016      0
# 23478    January 15, 2016      0
# 23479    January 14, 2016      0
# 23480    January 12, 2016      0
#
# [44898 rows x 5 columns]

# %% [markdown]
# ***Inspecting Length of News titles***

# %%
titles = [text for text in df.title]

max_len = 0
titles_len = []
for title in titles:
    titles_len.append(len(title.split()))
    max_len = max(len(title.split()), max_len)

print('Number of titles:', len(titles))
print('Max length of the titles:', max_len)
print('Mean length of the titles:', np.mean(titles_len))
# Out:
# Number of titles: 44898
# Max length of the titles: 42
# Mean length of the titles: 12.453472315025168

# %% [markdown]
# ***Inspecting length of News statements***

# %%
texts = [text for text in df.text]

max_len = 0
texts_len = []
for text in texts:
    texts_len.append(len(text.split()))
    max_len = max(len(text.split()), max_len)

print('Mean length of the texts:', np.mean(texts_len))
# Out:
# Mean length of the texts: 405.28228428883244

# %% [markdown]
# ***Purifying and shuffling the dataframe***

# %%
from sklearn.utils import shuffle

# Purify
df = df.iloc[:,[0, -1]]

# Shuffle
df = shuffle(df).reset_index(drop=True)

display(df)
# Out:
#                                                    title  label
# 0      Turkish police detain 25 suspected Islamic Sta...      1
# 1      Russian, Lebanese foreign ministers to meet in...      1
# 2      WATCH HERO Singlehandedly Shut Down Anti-Trump...      0
# 3       Trump Gives Newt Gingrich’s Wife Job As Vatic...      0
# 4       Trump Is Giddy About His Upcoming Meeting Wit...      0
# ...                                                  ...    ...
# 44893  Iranian political activist shot dead in Nether...      1
# 44894  German citizen freed in Turkey but banned from...      1
# 44895  U.S. appeals court upholds gag orders on FBI d...      1
# 44896  Irish finance minister says prospect of electi...      1
# 44897   Alabama’s Chief Justice Just Spit On The Cons...      0
#
# [44898 rows x 2 columns]

# %% [markdown]
# ***Splitting data into training, validation and testing.***

# %%
train_validate_df = df.sample(frac = 0.8)
test_df = df.drop(train_validate_df.index)

train_df = train_validate_df.sample(frac = 0.8)
validation_df = train_validate_df.drop(train_df.index)

# Reset Index
train_df = train_df.reset_index(drop=True)
validation_df = validation_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

print('train_dataset size:', train_df.shape)
print('validation_dataset size:', validation_df.shape)
print('testing_dataset size:', test_df.shape)
# Out:
# train_dataset size: (28734, 2)
# validation_dataset size: (7184, 2)
# testing_dataset size: (8980, 2)

# %%
train_df.to_csv('train.tsv', sep='\t', index=False)
validation_df.to_csv('val.tsv', sep='\t', index=False)
test_df.to_csv('test.tsv', sep='\t', index=False)

# %%
df = pd.concat([train_df, validation_df, test_df])
df.to_csv('non.csv',index=False)

# %%
import nltk
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
#def tokenize(column):
  #tokens = nltk.word_tokenize(column)
  #return [w for w in tokens if w.isalpha()]

# %%
#df['tokenized'] = df.apply(lambda x: tokenize(x['title']), axis=1)
#df[['tokenized']].head()

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
df = pd.read_csv('non.csv')

def lemmatize_word(word):
    return lemmatizer.lemmatize(word, pos='v')

df['lemmatized_column'] = df['title'].apply(lambda x: ' '.join([lemmatize_word(word) for word in x.split()]))

df.to_csv('lemmatized.csv', index=False)

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

# %%
print(stop_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'from', 'subject', 're', 'edu', 'use']

# %%
import gensim

# %%
def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3 and token not in stop_words:
            result.append(token)
            
    return result

# %%
df = pd.read_csv('lemmatized.csv')
df['clean'] = df['lemmatized_column'].apply(preprocess)
df
# Out:
#                                                    title  label  \
# 0      Bus bomb kills eight in Syria's Homs city: sta...      1
# 1       Putin Claims To Have Transcript Of White Hous...      0
# 2      U.S. House Republicans to discuss whether to i...      1
# 3      In Syria, Russia securing position as Assad pr...      1
# 4      Russia expects new sanctions to further sour i...      1
# ...                                                  ...    ...
# 44893  Peru's Fujimori asks for forgiveness, thanks K...      1
# 44894  FBI FILES REVEALED: VALERIE JARRETT’S FAMILY T...      0
# 44895  U OF CHICAGO Admissions Blames Trump For Chica...      0
# 44896  TUCKER CARLSON Tells Liberal Guest: National E...      0
# 44897  Iranian political activist shot dead in Nether...      1
#
#                                        lemmatized_column  \
# 0      Bus bomb kill eight in Syria's Homs city: stat...
# 1      Putin Claims To Have Transcript Of White House...
# 2      U.S. House Republicans to discuss whether to i...
# 3      In Syria, Russia secure position as Assad pres...
# 4      Russia expect new sanction to further sour its...
# ...                                                  ...
# 44893  Peru's Fujimori ask for forgiveness, thank Kuc...
# 44894  FBI FILES REVEALED: VALERIE JARRETT’S FAMILY T...
# 44895  U OF CHICAGO Admissions Blames Trump For Chica...
# 44896  TUCKER CARLSON Tells Liberal Guest: National E...
# 44897  Iranian political activist shoot dead in Nethe...
#
#                                                    clean
# 0          [bomb, kill, syria, homs, city, state, media]
# 1      [putin, claims, transcript, white, house, meet...
# 2          [house, republicans, discuss, impeach, chief]
# 3        [syria, russia, secure, position, assad, press]
# 4                       [russia, expect, sanction, sour]
# ...                                                  ...
# 44893  [peru, fujimori, forgiveness, thank, kuczynski...
# 44894  [files, revealed, valerie, jarrett, family, ti...
# 44895  [chicago, admissions, blames, trump, chicago, ...
# 44896  [tucker, carlson, tells, liberal, guest, natio...
# 44897  [iranian, political, activist, shoot, dead, ne...
#
# [44898 rows x 4 columns]

# %%
list_of_words = []
for i in df.clean:
    for j in i:
        list_of_words.append(j)

total_words = len(list(set(list_of_words)))
total_words
# Out:
# 18490

# %%
pip list | grep tensorflow
# Out:
# tensorflow                    2.12.0
# tensorflow-datasets           4.8.3
# tensorflow-estimator          2.12.0
# tensorflow-gcs-config         2.12.0
# tensorflow-hub                0.13.0
# tensorflow-io-gcs-filesystem  0.32.0
# tensorflow-metadata           1.13.1
# tensorflow-probability        0.19.0

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Embedding, Input, LSTM, Conv1D, MaxPool1D, Bidirectional, Dropout, BatchNormalization
import numpy as np

# %%
# Load the data
train_data = pd.read_csv('train.tsv', delimiter='\t')
test_data = pd.read_csv('test.tsv', delimiter='\t')
validation_data = pd.read_csv('val.tsv', delimiter='\t')

# %%
# Creating A Tokenizer To Tokenize The Words And Create Sequences Of Tokenized Words
tokenizer = Tokenizer(num_words = total_words)
tokenizer.fit_on_texts(train_df['title'])

# Convert the texts to sequences
train_sequences = tokenizer.texts_to_sequences(train_data['title'])
validation_sequences = tokenizer.texts_to_sequences(validation_data['title'])
test_sequences = tokenizer.texts_to_sequences(test_data['title'])

# %%
# Get the maximum sequence length
max_sequence_length = max(len(seq) for seq in train_sequences)
max_sequence_length
# Out:
# 44

# %%
# Pad the sequences
train_padded = pad_sequences(train_sequences, maxlen=max_sequence_length, padding='post', truncating='post')
test_padded = pad_sequences(test_sequences, maxlen=max_sequence_length, padding='post', truncating='post')
validation_padded = pad_sequences(validation_sequences, maxlen=max_sequence_length, padding='post', truncating='post')

# %%
# import numpy as np
# import fasttext

# # Download FastText embeddings
# fasttext_model = gensim.models.KeyedVectors.load_word2vec_format('/content/drive/MyDrive/Btech_project/cc.en.300.bin', binary=False,encoding='None')

# # Load Glove embeddings
# glove_embeddings = {}
# with open('/content/drive/MyDrive/Btech_project/glove.6B.100d.txt', 'rb') as f:
#     for line in f:
#         values = line.decode('utf-8').split()
#         word = values[0]
#         coefs = np.asarray(values[1:], dtype='float32')
#         glove_embeddings[word] = coefs

# # Create the embedding matrix
# word_index = tokenizer.word_index
# num_words = len(word_index) + 1
# embedding_matrix = np.zeros((num_words, embedding_dim))
# for word, i in word_index.items():
#     glove_embedding_vector = glove_embeddings.get(word)
#     fasttext_embedding_vector = fasttext_model[word] if word in fasttext_model else None
#     if glove_embedding_vector is not None:
#         embedding_matrix[i] = np.concatenate([glove_embedding_vector, fasttext_embedding_vector])
#     elif fasttext_embedding_vector is not None:
#         embedding_matrix[i] = fasttext_embedding_vector

# %%
pip install fasttext
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fasttext
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pybind11>=2.2
#   Using cached pybind11-2.10.4-py3-none-any.whl (222 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext) (67.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fasttext) (1.22.4)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4393482 sha256=dc7eea45d36d924ee68194115cdda51d4b1e3c37aff7d2d3be262a8fb649e81f
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.2 pybind11-2.10.4

# %%
# Define the embedding dimension
embedding_dim = 300

# Load the FastText model
import fasttext
ft = fasttext.load_model('/content/drive/MyDrive/Btech_project/cc.en.300.bin')

# Create the embedding matrix
word_index = tokenizer.word_index
num_words = len(word_index) + 1
embedding_matrix = np.zeros((num_words, embedding_dim))
for word, i in word_index.items():
    embedding_vector = ft.get_word_vector(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, Input, Dense, Flatten, Conv1D, MaxPooling1D, LSTM, Bidirectional, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Define the LSTM model

from keras.regularizers import l2
input_layer = Input(shape=(max_sequence_length,), dtype='int32')
embedding_layer = Embedding(num_words, embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length)(input_layer)
lstm_layer = LSTM(units=32, dropout=0.5, recurrent_dropout=0.5)(embedding_layer)
#lstm_dropout_layer = Dropout(0.5)(lstm_layer)
output_layer = Dense(1, activation='sigmoid', kernel_regularizer=l2(0.01))(lstm_layer)
lstm_model = Model(inputs=input_layer, outputs=output_layer)

# %%
# Compile the LSTM model
lstm_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
print(lstm_model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 44)]              0
#
#  embedding (Embedding)       (None, 44, 300)           8013300
#
#  lstm (LSTM)                 (None, 32)                42624
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 8,055,957
# Trainable params: 8,055,957
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Train the LSTM model
lstm_model.fit(train_padded, train_data['label'], validation_data=(validation_padded, validation_data['label']), epochs=15, batch_size=32)
# Out:
# Epoch 1/15
# 898/898 [==============================] - 203s 222ms/step - loss: 0.2191 - accuracy: 0.9212 - val_loss: 0.1131 - val_accuracy: 0.9667
# Epoch 2/15
# 898/898 [==============================] - 182s 203ms/step - loss: 0.0837 - accuracy: 0.9795 - val_loss: 0.1029 - val_accuracy: 0.9699
# Epoch 3/15
# 898/898 [==============================] - 180s 200ms/step - loss: 0.0520 - accuracy: 0.9889 - val_loss: 0.1222 - val_accuracy: 0.9694
# Epoch 4/15
# 898/898 [==============================] - 182s 202ms/step - loss: 0.0377 - accuracy: 0.9932 - val_loss: 0.1814 - val_accuracy: 0.9633
# Epoch 5/15
# 898/898 [==============================] - 182s 202ms/step - loss: 0.0327 - accuracy: 0.9948 - val_loss: 0.1227 - val_accuracy: 0.9685
# Epoch 6/15
# 898/898 [==============================] - 181s 202ms/step - loss: 0.0268 - accuracy: 0.9962 - val_loss: 0.1340 - val_accuracy: 0.9697
# Epoch 7/15
# 898/898 [==============================] - 183s 203ms/step - loss: 0.0252 - accuracy: 0.9968 - val_loss: 0.1158 - val_accuracy: 0.9685
# Epoch 8/15
# 898/898 [==============================] - 179s 200ms/step - loss: 0.0228 - accuracy: 0.9973 - val_loss: 0.1467 - val_accuracy: 0.9663
# Epoch 9/15
# 898/898 [==============================] - 181s 202ms/step - loss: 0.0204 - accuracy: 0.9984 - val_loss: 0.1490 - val_accuracy: 0.9683
# Epoch 10/15
# 898/898 [==============================] - 181s 201ms/step - loss: 0.0197 - accuracy: 0.9985 - val_loss: 0.1538 - val_accuracy: 0.9667
# Epoch 11/15
# 898/898 [==============================] - 183s 204ms/step - loss: 0.0200 - accuracy: 0.9984 - val_loss: 0.1634 - val_accuracy: 0.9621
# Epoch 12/15
# 898/898 [==============================] - 182s 203ms/step - loss: 0.0185 - accuracy: 0.9989 - val_loss: 0.1440 - val_accuracy: 0.9674
# Epoch 13/15
# 898/898 [==============================] - 179s 200ms/step - loss: 0.0183 - accuracy: 0.9987 - val_loss: 0.1468 - val_accuracy: 0.9660
# Epoch 14/15
# 898/898 [==============================] - 181s 201ms/step - loss: 0.0180 - accuracy: 0.9990 - val_loss: 0.1661 - val_accuracy: 0.9671
# Epoch 15/15
# 898/898 [==============================] - 180s 200ms/step - loss: 0.0164 - accuracy: 0.9994 - val_loss: 0.1578 - val_accuracy: 0.9676

# %%
test_loss, test_acc = lstm_model.evaluate(test_padded, test_data['label'])
print('Test accuracy:', test_acc)
# Out:
# 281/281 [==============================] - 4s 16ms/step - loss: 0.1746 - accuracy: 0.9637
# Test accuracy: 0.963697075843811

# %%
#Define Bilstm model
input_layer = Input(shape=(max_sequence_length,), dtype='int32')
embedding_layer = Embedding(num_words, embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length)(input_layer)
lstm_layer = Bidirectional(LSTM(units=32, dropout=0.5, recurrent_dropout=0.5))(embedding_layer)
#lstm_dropout_layer = Dropout(0.5)(lstm_layer)
output_layer = Dense(1, activation='sigmoid', kernel_regularizer=l2(0.01))(lstm_layer)
bilstm_model = Model(inputs=input_layer, outputs=output_layer)

# %%
bilstm_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
print(bilstm_model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 44)]              0
#
#  embedding_1 (Embedding)     (None, 44, 300)           8013300
#
#  bidirectional (Bidirectiona  (None, 64)               85248
#  l)
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 8,098,613
# Trainable params: 8,098,613
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
bilstm_model.fit(train_padded, train_data['label'], validation_data=(validation_padded, validation_data['label']), epochs=15, batch_size=32)
# Out:
# Epoch 1/15
# 898/898 [==============================] - 258s 281ms/step - loss: 0.1624 - accuracy: 0.9456 - val_loss: 0.0970 - val_accuracy: 0.9734
# Epoch 2/15
# 898/898 [==============================] - 249s 277ms/step - loss: 0.0636 - accuracy: 0.9849 - val_loss: 0.0970 - val_accuracy: 0.9722
# Epoch 3/15
# 898/898 [==============================] - 250s 279ms/step - loss: 0.0392 - accuracy: 0.9926 - val_loss: 0.0980 - val_accuracy: 0.9723
# Epoch 4/15
# 898/898 [==============================] - 249s 278ms/step - loss: 0.0312 - accuracy: 0.9958 - val_loss: 0.1044 - val_accuracy: 0.9723
# Epoch 5/15
# 898/898 [==============================] - 250s 278ms/step - loss: 0.0254 - accuracy: 0.9980 - val_loss: 0.1116 - val_accuracy: 0.9716
# Epoch 6/15
# 898/898 [==============================] - 248s 276ms/step - loss: 0.0243 - accuracy: 0.9979 - val_loss: 0.1112 - val_accuracy: 0.9722
# Epoch 7/15
# 898/898 [==============================] - 251s 279ms/step - loss: 0.0219 - accuracy: 0.9986 - val_loss: 0.1393 - val_accuracy: 0.9666
# Epoch 8/15
# 898/898 [==============================] - 249s 278ms/step - loss: 0.0197 - accuracy: 0.9994 - val_loss: 0.1310 - val_accuracy: 0.9673
# Epoch 9/15
# 898/898 [==============================] - 249s 278ms/step - loss: 0.0193 - accuracy: 0.9991 - val_loss: 0.1249 - val_accuracy: 0.9699
# Epoch 10/15
# 898/898 [==============================] - 248s 277ms/step - loss: 0.0188 - accuracy: 0.9992 - val_loss: 0.1323 - val_accuracy: 0.9652
# Epoch 11/15
# 898/898 [==============================] - 248s 277ms/step - loss: 0.0179 - accuracy: 0.9995 - val_loss: 0.1297 - val_accuracy: 0.9687
# Epoch 12/15
# 898/898 [==============================] - 247s 276ms/step - loss: 0.0176 - accuracy: 0.9996 - val_loss: 0.1246 - val_accuracy: 0.9695
# Epoch 13/15
# 898/898 [==============================] - 250s 278ms/step - loss: 0.0165 - accuracy: 0.9999 - val_loss: 0.1362 - val_accuracy: 0.9666
# Epoch 14/15
# 898/898 [==============================] - 248s 276ms/step - loss: 0.0168 - accuracy: 0.9997 - val_loss: 0.1535 - val_accuracy: 0.9634
# Epoch 15/15
# 898/898 [==============================] - 247s 275ms/step - loss: 0.0166 - accuracy: 0.9996 - val_loss: 0.1437 - val_accuracy: 0.9653

# %%
test_loss, test_acc = bilstm_model.evaluate(test_padded, test_data['label'])
print('Test accuracy:', test_acc)
# Out:
# 281/281 [==============================] - 5s 19ms/step - loss: 0.1357 - accuracy: 0.9673
# Test accuracy: 0.9672605991363525

# %%
#Define the CNN-BiLSTM model


input_layer = Input(shape=(max_sequence_length,), dtype='int32')
embedding_layer = Embedding(num_words, embedding_dim, weights=[embedding_matrix], input_length=max_sequence_length)(input_layer)
embedding_dropout_layer = Dropout(0.5)(embedding_layer)
conv_layer = Conv1D(filters=16, kernel_size=3, padding='same', activation='relu')(embedding_dropout_layer)
conv_dropout_layer = Dropout(0.5)(conv_layer)
pool_layer = MaxPooling1D(pool_size=2)(conv_dropout_layer)
bilstm_layer = Bidirectional(LSTM(units=32, dropout=0.5, recurrent_dropout=0.5))(pool_layer)
bilstm_dropout_layer = Dropout(0.5)(bilstm_layer)
output_layer = Dense(1, activation='sigmoid', kernel_regularizer=l2(0.01))(bilstm_dropout_layer)
cnn_bilstm_model = Model(inputs=input_layer, outputs=output_layer)

# %%
print(cnn_bilstm_model.summary())
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 44)]              0
#
#  embedding_2 (Embedding)     (None, 44, 300)           8013300
#
#  dropout (Dropout)           (None, 44, 300)           0
#
#  conv1d (Conv1D)             (None, 44, 16)            14416
#
#  dropout_1 (Dropout)         (None, 44, 16)            0
#
#  max_pooling1d (MaxPooling1D  (None, 22, 16)           0
#  )
#
#  bidirectional_1 (Bidirectio  (None, 64)               12544
#  nal)
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 8,040,325
# Trainable params: 8,040,325
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Compile the CNN-BiLSTM model
cnn_bilstm_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
#Train the CNN-BiLSTM model
cnn_bilstm_model.fit(train_padded, train_data['label'], validation_data=(validation_padded, validation_data['label']), epochs=15, batch_size=32)
# Out:
# Epoch 1/15
# 898/898 [==============================] - 166s 177ms/step - loss: 0.2159 - accuracy: 0.9173 - val_loss: 0.1059 - val_accuracy: 0.9681
# Epoch 2/15
# 898/898 [==============================] - 158s 176ms/step - loss: 0.0923 - accuracy: 0.9738 - val_loss: 0.1090 - val_accuracy: 0.9645
# Epoch 3/15
# 898/898 [==============================] - 162s 180ms/step - loss: 0.0630 - accuracy: 0.9839 - val_loss: 0.0970 - val_accuracy: 0.9704
# Epoch 4/15
# 898/898 [==============================] - 159s 177ms/step - loss: 0.0481 - accuracy: 0.9888 - val_loss: 0.1091 - val_accuracy: 0.9691
# Epoch 5/15
# 898/898 [==============================] - 158s 176ms/step - loss: 0.0400 - accuracy: 0.9910 - val_loss: 0.1073 - val_accuracy: 0.9709
# Epoch 6/15
# 898/898 [==============================] - 157s 175ms/step - loss: 0.0331 - accuracy: 0.9935 - val_loss: 0.1242 - val_accuracy: 0.9706
# Epoch 7/15
# 898/898 [==============================] - 158s 176ms/step - loss: 0.0299 - accuracy: 0.9946 - val_loss: 0.1186 - val_accuracy: 0.9695
# Epoch 8/15
# 898/898 [==============================] - 162s 180ms/step - loss: 0.0265 - accuracy: 0.9952 - val_loss: 0.1333 - val_accuracy: 0.9676
# Epoch 9/15
# 898/898 [==============================] - 157s 175ms/step - loss: 0.0243 - accuracy: 0.9960 - val_loss: 0.1328 - val_accuracy: 0.9691
# Epoch 10/15
# 898/898 [==============================] - 159s 177ms/step - loss: 0.0222 - accuracy: 0.9965 - val_loss: 0.1324 - val_accuracy: 0.9678
# Epoch 11/15
# 898/898 [==============================] - 159s 177ms/step - loss: 0.0200 - accuracy: 0.9975 - val_loss: 0.1406 - val_accuracy: 0.9660
# Epoch 12/15
# 898/898 [==============================] - 161s 179ms/step - loss: 0.0195 - accuracy: 0.9971 - val_loss: 0.1333 - val_accuracy: 0.9704
# Epoch 13/15
# 898/898 [==============================] - 159s 177ms/step - loss: 0.0192 - accuracy: 0.9974 - val_loss: 0.1410 - val_accuracy: 0.9688
# Epoch 14/15
# 898/898 [==============================] - 159s 177ms/step - loss: 0.0185 - accuracy: 0.9979 - val_loss: 0.1549 - val_accuracy: 0.9671
# Epoch 15/15
# 898/898 [==============================] - 158s 176ms/step - loss: 0.0181 - accuracy: 0.9981 - val_loss: 0.1354 - val_accuracy: 0.9690

# %%
test_loss, test_acc = cnn_bilstm_model.evaluate(test_padded, test_data['label'])
print('Test accuracy:', test_acc)
# Out:
# 281/281 [==============================] - 3s 12ms/step - loss: 0.1411 - accuracy: 0.9680
# Test accuracy: 0.9680401086807251
